# %% [markdown]
# <a href="https://colab.research.google.com/github/michelucci/oreilly-london-ai/blob/master/day1/First_Example_of_a_CNN_(CIFAR10).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # House number predictor

# %% [markdown]
# ## Load the SVHN Dataset
# Obtain the SVHN dataset from https://www.kaggle.com/datasets/sasha18/street-view-house-nos-h5-file/
# Extract the .h5 file from inside the archive
# Load the dataset using

# %%
import h5py
import numpy as np
with h5py.File('SVHN_single_grey1.h5', 'r') as file:
  x_train = np.array(file['X_train'])
  y_train = np.array(file['y_train'])
  x_test = np.array(file['X_test'])
  y_test = np.array(file['y_test'])
  x_val = np.array(file['X_val'])
  y_val = np.array(file['y_val'])

# %% [markdown]
# # Preprocess the Data
# Explore and visualize a few images from the dataset.

# %%
# Render the first 10 images
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 4))  # Adjust as needed
for i in range(10):
    plt.subplot(2, 5, i+1)
    # Display image and label here
    plt.imshow(x_train[i])
    plt.title(y_train[i])
plt.tight_layout()
plt.show()


# Explore and visualize the dataset
print('Training data shape : ', x_train.shape, y_train.shape)
# Out:
# Training data shape :  (42000, 32, 32) (42000,)

# %%
# Normalize the pixel values of the images to the range [0, 1].
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255
x_val = x_val.astype('float32')/255

# Reshape the input to make it compatible to the CNN model
x_train = x_train.reshape(-1, 32, 32, 1)
x_test = x_test.reshape(-1, 32, 32, 1)
x_val = x_val.reshape(-1, 32, 32, 1)

from keras.utils import to_categorical

# Assuming y_train and y_test are your target data
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)
y_val = to_categorical(y_val, num_classes=10)

# %% [markdown]
# ## Build a Convolutional Neural Network (CNN)
#
# Create a CNN model suitable for image classification.
# Design the architecture with convolutional layers, pooling layers, and dense layers.
# Compile the model with an appropriate optimizer, loss function, and metric.

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
import keras.backend as K
from keras.optimizers import Adam

# Clear any existing model from memory
K.clear_session()

# Define Model
model = Sequential([
  Conv2D(16, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 1)),
  MaxPooling2D(pool_size=(2, 2)),
  Flatten(),
  Dense(10, activation='softmax')
])

# Compile the model
model.compile(
  optimizer=Adam(learning_rate=0.0005),
  loss='categorical_crossentropy',
  metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 16)        160
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 16)        0
#  D)
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 10)                40970
#
# =================================================================
# Total params: 41130 (160.66 KB)
# Trainable params: 41130 (160.66 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Train the Model
#
# Train the model on the SVHN training data.
# Monitor the training process using validation data.
# Aim for high accuracy and consider experimenting with hyperparameters.

# %%
# Train model
history = model.fit(
  x_train,
  y_train,
  batch_size=128,
  epochs=50,
  verbose=1, 
  validation_data=(x_val, y_val)
)
# Out:
# Epoch 1/50
# 329/329 [==============================] - 4s 10ms/step - loss: 2.2431 - accuracy: 0.2400 - val_loss: 2.1292 - val_accuracy: 0.4077
# Epoch 2/50
# 329/329 [==============================] - 3s 9ms/step - loss: 1.9425 - accuracy: 0.4944 - val_loss: 1.7271 - val_accuracy: 0.5695
# Epoch 3/50
# 329/329 [==============================] - 3s 9ms/step - loss: 1.5555 - accuracy: 0.6230 - val_loss: 1.4003 - val_accuracy: 0.6644
# Epoch 4/50
# 329/329 [==============================] - 3s 9ms/step - loss: 1.3000 - accuracy: 0.6844 - val_loss: 1.2026 - val_accuracy: 0.7017
# Epoch 5/50
# 329/329 [==============================] - 3s 9ms/step - loss: 1.1427 - accuracy: 0.7142 - val_loss: 1.0807 - val_accuracy: 0.7294
# Epoch 6/50
# 329/329 [==============================] - 3s 9ms/step - loss: 1.0370 - accuracy: 0.7389 - val_loss: 0.9919 - val_accuracy: 0.7511
# Epoch 7/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.9590 - accuracy: 0.7551 - val_loss: 0.9283 - val_accuracy: 0.7650
# Epoch 8/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.8995 - accuracy: 0.7671 - val_loss: 0.8774 - val_accuracy: 0.7735
# Epoch 9/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.8518 - accuracy: 0.7785 - val_loss: 0.8319 - val_accuracy: 0.7871
# Epoch 10/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.8113 - accuracy: 0.7897 - val_loss: 0.7967 - val_accuracy: 0.7954
# Epoch 11/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.7778 - accuracy: 0.7977 - val_loss: 0.7685 - val_accuracy: 0.7914
# Epoch 12/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.7481 - accuracy: 0.8037 - val_loss: 0.7396 - val_accuracy: 0.8070
# Epoch 13/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.7225 - accuracy: 0.8087 - val_loss: 0.7155 - val_accuracy: 0.8097
# Epoch 14/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.7008 - accuracy: 0.8142 - val_loss: 0.6948 - val_accuracy: 0.8190
# Epoch 15/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.6806 - accuracy: 0.8207 - val_loss: 0.6785 - val_accuracy: 0.8200
# Epoch 16/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.6635 - accuracy: 0.8231 - val_loss: 0.6639 - val_accuracy: 0.8258
# Epoch 17/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.6487 - accuracy: 0.8279 - val_loss: 0.6494 - val_accuracy: 0.8260
# Epoch 18/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.6350 - accuracy: 0.8301 - val_loss: 0.6356 - val_accuracy: 0.8303
# Epoch 19/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.6227 - accuracy: 0.8331 - val_loss: 0.6285 - val_accuracy: 0.8292
# Epoch 20/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.6123 - accuracy: 0.8365 - val_loss: 0.6200 - val_accuracy: 0.8356
# Epoch 21/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.6025 - accuracy: 0.8388 - val_loss: 0.6082 - val_accuracy: 0.8375
# Epoch 22/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.5924 - accuracy: 0.8412 - val_loss: 0.6073 - val_accuracy: 0.8335
# Epoch 23/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.5845 - accuracy: 0.8428 - val_loss: 0.5916 - val_accuracy: 0.8421
# Epoch 24/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.5768 - accuracy: 0.8438 - val_loss: 0.5886 - val_accuracy: 0.8446
# Epoch 25/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.5704 - accuracy: 0.8463 - val_loss: 0.5814 - val_accuracy: 0.8444
# Epoch 26/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.5637 - accuracy: 0.8472 - val_loss: 0.5767 - val_accuracy: 0.8450
# Epoch 27/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.5574 - accuracy: 0.8497 - val_loss: 0.5711 - val_accuracy: 0.8464
# Epoch 28/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.5522 - accuracy: 0.8514 - val_loss: 0.5659 - val_accuracy: 0.8472
# Epoch 29/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.5466 - accuracy: 0.8519 - val_loss: 0.5638 - val_accuracy: 0.8469
# Epoch 30/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.5421 - accuracy: 0.8537 - val_loss: 0.5603 - val_accuracy: 0.8476
# Epoch 31/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.5379 - accuracy: 0.8536 - val_loss: 0.5579 - val_accuracy: 0.8490
# Epoch 32/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.5341 - accuracy: 0.8551 - val_loss: 0.5510 - val_accuracy: 0.8524
# Epoch 33/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.5294 - accuracy: 0.8550 - val_loss: 0.5463 - val_accuracy: 0.8524
# Epoch 34/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.5257 - accuracy: 0.8566 - val_loss: 0.5518 - val_accuracy: 0.8495
# Epoch 35/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.5237 - accuracy: 0.8559 - val_loss: 0.5423 - val_accuracy: 0.8540
# Epoch 36/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.5192 - accuracy: 0.8577 - val_loss: 0.5384 - val_accuracy: 0.8558
# Epoch 37/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.5150 - accuracy: 0.8587 - val_loss: 0.5339 - val_accuracy: 0.8560
# Epoch 38/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.5121 - accuracy: 0.8597 - val_loss: 0.5338 - val_accuracy: 0.8551
# Epoch 39/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.5093 - accuracy: 0.8607 - val_loss: 0.5324 - val_accuracy: 0.8554
# Epoch 40/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.5078 - accuracy: 0.8610 - val_loss: 0.5331 - val_accuracy: 0.8566
# Epoch 41/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.5054 - accuracy: 0.8612 - val_loss: 0.5254 - val_accuracy: 0.8577
# Epoch 42/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.5026 - accuracy: 0.8620 - val_loss: 0.5274 - val_accuracy: 0.8555
# Epoch 43/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.4996 - accuracy: 0.8624 - val_loss: 0.5292 - val_accuracy: 0.8557
# Epoch 44/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.4977 - accuracy: 0.8624 - val_loss: 0.5217 - val_accuracy: 0.8583
# Epoch 45/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.4959 - accuracy: 0.8623 - val_loss: 0.5213 - val_accuracy: 0.8605
# Epoch 46/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.4927 - accuracy: 0.8642 - val_loss: 0.5266 - val_accuracy: 0.8556
# Epoch 47/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.4912 - accuracy: 0.8643 - val_loss: 0.5154 - val_accuracy: 0.8591
# Epoch 48/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.4907 - accuracy: 0.8634 - val_loss: 0.5154 - val_accuracy: 0.8611
# Epoch 49/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.4873 - accuracy: 0.8647 - val_loss: 0.5178 - val_accuracy: 0.8581
# Epoch 50/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.4868 - accuracy: 0.8649 - val_loss: 0.5141 - val_accuracy: 0.8607

# %% [markdown]
# ## Evaluate the Model
# Evaluate the trained model on the SVHN test data.
# Analyze the classification performance and accuracy.

# %%
plt.figure(figsize=[16,6])

# Loss Curves
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'],'black',linewidth=3.0)
plt.plot(history.history['val_loss'],'black',ls = '--', linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)

# Accuracy Curves
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'],'black',linewidth=3.0)
plt.plot(history.history['val_accuracy'],'black',ls = '--',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18, loc = 'lower right')
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualize Predictions
#
# Choose a few images from the test set and visualize the model's predictions.
# Explore cases where the model succeeded and where it might have struggled.

# %%
#Choose a few images from the test set  and visualize the model's predictions

# Create a confusion matrix to see where the model is getting confused
from sklearn.metrics import confusion_matrix
import seaborn as sns
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)
confusion_mtx = confusion_matrix(y_true, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='d')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
plt.show()
# Out:
#   1/563 [..............................] - ETA: 19s
# 563/563 [==============================] - 1s 1ms/step

# %% [markdown]
# # Improve the model
# - Start as simple as possible
# - Increase learning rate
# - Add more layers
